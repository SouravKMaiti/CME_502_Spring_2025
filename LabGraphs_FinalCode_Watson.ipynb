# %% [markdown]
# The imported and graphed raw data for my final code. Only a small section will be interpolated and fitted as proof of concept in the final code

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('nafion 117 SCCM60 1.txt')
data.columns=['Voltage_V','Current_A','Power_W']
#trial 1 90 psi
data2=pd.read_csv('nafion 117 SCCM60 2.txt')
data2.columns=['Voltage_V','Current_A','Power_W']
#trail 2 90 psi
data3=pd.read_csv('nafion 117 SCCM60 3.txt')
data3.columns=['Voltage_V','Current_A','Power_W']
# trial 3 90 psi
plt.figure(figsize=(80,8))
plt.subplot(1, 6, 1)
plt.scatter(data['Current_A'],data['Voltage_V'], label="data")
plt.plot(data['Current_A'],data['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 1 60 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 2)
plt.scatter(data2['Current_A'],data2['Voltage_V'], label="data")
plt.plot(data2['Current_A'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 2 60 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 3)
plt.scatter(data3['Current_A'],data3['Voltage_V'],label="data")
plt.plot(data3['Current_A'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 3 60 psi")
plt.legend()
#^the third trial

#power vs current behavior:
plt.figure(figsize=(80,8))

plt.subplot(1, 6, 4)
plt.scatter(data['Power_W'],data['Voltage_V'], label="data")
#plt.plot(data['Power_W'],data['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current density")
plt.title("Trail 1 60 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 5)
plt.scatter(data2['Power_W'],data2['Voltage_V'], label="data")
#plt.plot(data2['Power_W'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current density")
plt.title("Trail 2 60 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 6)
plt.scatter(data3['Power_W'],data3['Voltage_V'], label="data")
#plt.plot(data3['Power_W'],data3['Voltage_V'],'r--',label="data")
plt.ylabel("Power in watts")
plt.xlabel("current density")
plt.title("Trail 3 60 psi")
plt.legend()
#^the third trial
# Now we want to know for sure where the slope is changing so we will use the 
#numpy gradient function:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('nafion 117 SCCM90 1.txt')
data.columns=['Voltage_V','Current_A','Power_W']
#trial 1 90 psi
data2=pd.read_csv('nafion 117 SCCM90 2.txt')
data2.columns=['Voltage_V','Current_A','Power_W']
#trail 2 90 psi
data3=pd.read_csv('nafion 117 SCCM90 3.txt')
data3.columns=['Voltage_V','Current_A','Power_W']
# trial 3 90 psi
plt.figure(figsize=(80,8))
plt.subplot(1, 6, 1)
plt.scatter(data['Current_A'],data['Voltage_V'], label="data")
plt.plot(data['Current_A'],data['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 1 90 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 2)
plt.scatter(data2['Current_A'],data2['Voltage_V'], label="data")
plt.plot(data2['Current_A'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 2 90 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 3)
plt.scatter(data3['Current_A'],data3['Voltage_V'],label="data")
plt.plot(data3['Current_A'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 3 90 psi")
plt.legend()
#^the third trial

#power vs current behavior:
plt.figure(figsize=(80,8))

plt.subplot(1, 6, 4)
plt.scatter(data['Power_W'],data['Voltage_V'], label="data")
plt.plot(data['Power_W'],data['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 1 90 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 5)
plt.scatter(data2['Power_W'],data2['Voltage_V'], label="data")
plt.plot(data2['Power_W'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 2 90 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 6)
plt.scatter(data3['Power_W'],data3['Voltage_V'], label="data")
plt.plot(data3['Power_W'],data3['Voltage_V'],'r--',label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 3 90 psi")
plt.legend()
#^the third trial
# Now we want to know for sure where the slope is changing so we will use the 
#numpy gradient function:

# %%
#the 90 psi trial N117
#lab data:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('nafion 117 SCCM120 1.txt')
data.columns=['Voltage_V','Current_A','Power_W']
#trial 1 90 psi
data2=pd.read_csv('nafion 117 SCCM120 2.txt')
data2.columns=['Voltage_V','Current_A','Power_W']
#trail 2 90 psi
data3=pd.read_csv('nafion 117 SCCM120 3.txt')
data3.columns=['Voltage_V','Current_A','Power_W']
# trial 3 90 psi
plt.figure(figsize=(80,8))
plt.subplot(1, 6, 1)
plt.scatter(data['Current_A'],data['Voltage_V'], label="data")
plt.plot(data['Current_A'],data['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 1 120 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 2)
plt.scatter(data2['Current_A'],data2['Voltage_V'], label="data")
plt.plot(data2['Current_A'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 2 120 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 3)
plt.scatter(data3['Current_A'],data3['Voltage_V'],label="data")
plt.plot(data3['Current_A'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Trail 3 120 psi")
plt.legend()
#^the third trial

#power vs current behavior:
plt.figure(figsize=(80,8))

plt.subplot(1, 6, 4)
plt.scatter(data['Power_W'],data['Voltage_V'], label="data")
plt.plot(data['Power_W'],data['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 1 120 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 5)
plt.scatter(data2['Power_W'],data2['Voltage_V'], label="data")
plt.plot(data2['Power_W'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 2 120 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 6)
plt.scatter(data3['Power_W'],data3['Voltage_V'], label="data")
plt.plot(data3['Power_W'],data3['Voltage_V'],'r--',label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 3 120 psi")
plt.legend()
#^the third trial
# Now we want to know for sure where the slope is changing so we will use the 
#numpy gradient function:

# %%
#lab data:
# 120 trial nafion 115
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('nafion 115 SCCM60 1.txt')
data.columns=['Voltage_V','Current_A','Power_W']
#trial 1 120 psi
data2=pd.read_csv('nafion 115 SCCM60 2.txt')
data2.columns=['Voltage_V','Current_A','Power_W']
#trail 2 120 psi
data3=pd.read_csv('nafion 115 SCCM60 3.txt')
data3.columns=['Voltage_V','Current_A','Power_W']
# trial 3 120 psi
plt.figure(figsize=(80,8))
plt.subplot(1, 6, 1)
plt.scatter(data['Current_A'],data['Voltage_V'], label="data")
plt.plot(data['Current_A'],data['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current in amps")
plt.title("Trail 1 120 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 2)
plt.scatter(data2['Current_A'],data2['Voltage_V'], label="data")
plt.plot(data2['Current_A'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current in amps")
plt.title("Trail 2 120 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 3)
plt.scatter(data3['Current_A'],data3['Voltage_V'], label="data")
plt.plot(data3['Current_A'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current in amps")
plt.title("Trail 3 60 psi")
plt.legend()
#^the third trial

#power vs current behavior:
plt.figure(figsize=(80,8))

plt.subplot(1, 6, 4)
plt.scatter(data['Power_W'],data['Voltage_V'], label="data")
plt.plot(data['Power_W'],data['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 1 60 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 5)
plt.scatter(data2['Power_W'],data2['Voltage_V'], label="data")
plt.plot(data2['Power_W'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 2 60 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 6)
plt.scatter(data3['Power_W'],data3['Voltage_V'], label="data")
plt.plot(data3['Power_W'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 3 60 psi")
plt.legend()
#^the third trial
#combine the data then graph it. then interpolate

# %%
#lab data:
# 120 trial nafion 115
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('nafion 115 SCCM90 1.txt')
data.columns=['Voltage_V','Current_A','Power_W']
#trial 1 120 psi
data2=pd.read_csv('nafion 115 SCCM90 2.txt')
data2.columns=['Voltage_V','Current_A','Power_W']
#trail 2 120 psi
data3=pd.read_csv('nafion 115 SCCM90 3.txt')
data3.columns=['Voltage_V','Current_A','Power_W']
#
plt.figure(figsize=(80,8))
plt.subplot(1, 6, 1)
plt.scatter(data['Current_A'],data['Voltage_V'], label="data")
plt.plot(data['Current_A'],data['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density")
plt.title("Nafion 117 90 psi trial 1")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 2)
plt.scatter(data2['Current_A'],data2['Voltage_V'], label="data")
plt.plot(data2['Current_A'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current density amps/cm^2")
plt.title("Trail 2 90 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 3)
plt.scatter(data3['Current_A'],data3['Voltage_V'], label="data")
plt.plot(data3['Current_A'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current in amps")
plt.title("Trail 3 90 psi")
plt.legend()
#^the third trial

#power vs current behavior:
plt.figure(figsize=(80,8))

plt.subplot(1, 6, 4)
plt.scatter(data['Power_W'],data['Voltage_V'], label="data")
plt.plot(data['Power_W'],data['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 1 90 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 5)
plt.scatter(data2['Power_W'],data2['Voltage_V'], label="data")
plt.plot(data2['Power_W'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 2 90 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 6)
plt.scatter(data3['Power_W'],data3['Voltage_V'], label="data")
plt.plot(data3['Power_W'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 3 90 psi")
plt.legend()
#^the third trial
#combine the data then graph it. then interpolate
#try polyfit...

# %%
#lab data:
# 120 trial nafion 115
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('nafion 115 SCCM120 1.txt')
data.columns=['Voltage_V','Current_A','Power_W']
#trial 1 120 psi
data2=pd.read_csv('nafion 115 SCCM120 2.txt')
data2.columns=['Voltage_V','Current_A','Power_W']
#trail 2 120 psi
data3=pd.read_csv('nafion 115 SCCM120 3.txt')
data3.columns=['Voltage_V','Current_A','Power_W']
# trial 3 120 psi
plt.figure(figsize=(80,8))
plt.subplot(1, 6, 1)
plt.scatter(data['Current_A'],data['Voltage_V'], label="data")
plt.plot(data['Current_A'],data['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current in amps")
plt.title("Trail 1 120 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 2)
plt.scatter(data2['Current_A'],data2['Voltage_V'], label="data")
plt.plot(data2['Current_A'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current in amps")
plt.title("Trail 2 120 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 3)
plt.scatter(data3['Current_A'],data3['Voltage_V'], label="data")
plt.plot(data3['Current_A'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("voltage in volts")
plt.xlabel("current in amps")
plt.title("Trail 3 120 psi")
plt.legend()
#^the third trial

#power vs current behavior:
plt.figure(figsize=(80,8))

plt.subplot(1, 6, 4)
plt.scatter(data['Power_W'],data['Voltage_V'], label="data")
plt.plot(data['Power_W'],data['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 1 120 psi")
plt.legend()
#^ the first trial
plt.subplot(1, 6, 5)
plt.scatter(data2['Power_W'],data2['Voltage_V'], label="data")
plt.plot(data2['Power_W'],data2['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 2 120 psi")
plt.legend()
#^the second trial
plt.subplot(1, 6, 6)
plt.scatter(data3['Power_W'],data3['Voltage_V'], label="data")
plt.plot(data3['Power_W'],data3['Voltage_V'],'r--', label="data")
plt.ylabel("Power in watts")
plt.xlabel("current in amps")
plt.title("Trail 3 120 psi")
plt.legend()
#^the third trial
#combine the data then graph it. then interpolate
